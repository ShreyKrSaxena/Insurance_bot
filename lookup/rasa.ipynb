# %%
# %matplotlib inline

import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\my-venv\\Scripts\\weatherbot\\rasabot\\cloned_repo\\12-5-19_ChatbotUsingRasa_AnujSaini\\MainProject'

# %%
import sys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-75ac2534ea6b> in <module>
#       1 import sys
# ----> 2 pwd
#
# NameError: name 'pwd' is not defined

# %%
import sys
python = sys.executable

# In your environment run:
# !{python} -m pip install -U rasa_core rasa_nlu[spacy];
# Out:
# Collecting rasa_core
#   Using cached https://files.pythonhosted.org/packages/cd/7b/58a6a997023a8b1f6a0e292d08fd88b4d39ec325e103c6cebd1eb38f6545/rasa_core-0.14.5-py3-none-any.whl
# Collecting rasa_nlu[spacy]
#   Using cached https://files.pythonhosted.org/packages/19/c4/c6146c445a17b6ce414d773f93c941c44ca16720609000ae3d01409f9dfb/rasa_nlu-0.15.1-py3-none-any.whl
# Collecting mattermostwrapper~=2.0
#   Using cached https://files.pythonhosted.org/packages/93/70/203660597d12788e958dd691aa11c3c29caa075eadb2ce94d2eb53099d1b/mattermostwrapper-2.1-py2.py3-none-any.whl
# Collecting python-telegram-bot~=11.0
#   Using cached https://files.pythonhosted.org/packages/84/6c/47932a4041ee76650ad1f45a80e1422077e1e99c08a4d7a61cfbe5393d41/python_telegram_bot-11.1.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: gevent~=1.3 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (1.4.0)
# Collecting redis~=2.0
#   Downloading https://files.pythonhosted.org/packages/3b/f6/7a76333cf0b9251ecf49efff635015171843d9b977e4ffcf59f9c4428052/redis-2.10.6-py2.py3-none-any.whl (64kB)
# Collecting twilio~=6.0
#   Downloading https://files.pythonhosted.org/packages/d6/99/3dae71dcb8642226c9f2a25fb2f1437a3a35de89aebefd870e053e947ba9/twilio-6.33.0.tar.gz (392kB)
# Collecting scikit-learn~=0.20.0
#   Using cached https://files.pythonhosted.org/packages/bc/d2/256a17cf179681b257f76ac9a60312bd9e0f80e073aedd4d4fff9b2fa2c5/scikit_learn-0.20.4-cp37-cp37m-win_amd64.whl
# Collecting ruamel.yaml~=0.15.0
#   Using cached https://files.pythonhosted.org/packages/f8/c0/2d589e20427441ed22adb896ea4edb2485dc2a37b2d711461df470d35807/ruamel.yaml-0.15.100-cp37-cp37m-win_amd64.whl
# Requirement already satisfied, skipping upgrade: networkx~=2.2 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (2.4)
# Collecting fakeredis~=0.10.0
#   Downloading https://files.pythonhosted.org/packages/64/bd/2756ddf350c4bb308e3255f9dcd6610f8b01344947bf74d5d166dc66b0a2/fakeredis-0.10.3-py2.py3-none-any.whl
# Collecting pymongo~=3.7
#   Using cached https://files.pythonhosted.org/packages/c9/36/715c4ccace03a20cf7e8f15a670f651615744987af62fad8b48bea8f65f9/pymongo-3.9.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied, skipping upgrade: apscheduler~=3.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (3.6.1)
# Processing c:\users\asus\appdata\local\pip\cache\wheels\3b\d4\92\3458f0e1a3e1a9c8935d3b2db89a75d74d8d45601fedec752f\slackclient-1.3.2-py2.py3-none-any.whl
# Collecting pytz~=2018.9
#   Using cached https://files.pythonhosted.org/packages/61/28/1d3920e4d1d50b19bc5d24398a7cd85cc7b9a75a490570d5a30c57622d34/pytz-2018.9-py2.py3-none-any.whl
# Collecting pika~=0.12.0
#   Using cached https://files.pythonhosted.org/packages/bf/48/72de47f63ba353bacd74b76bb65bc63620b0706d8b0471798087cd5a4916/pika-0.12.0-py2.py3-none-any.whl
# Collecting questionary>=1.0.1
#   Using cached https://files.pythonhosted.org/packages/c2/f9/8a6e7fce60566b3bcdc5ad0923916f38a65bca630ce3647251e672308bdf/questionary-1.3.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: scipy~=1.2 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (1.3.1)
# Requirement already satisfied, skipping upgrade: requests~=2.20 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (2.22.0)
# Processing c:\users\asus\appdata\local\pip\cache\wheels\30\6b\50\6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e\terminaltables-3.1.0-cp37-none-any.whl
# Collecting pydot~=1.4
#   Using cached https://files.pythonhosted.org/packages/33/d1/b1479a770f66d962f545c2101630ce1d5592d90cb4f083d38862e93d16d2/pydot-1.4.1-py2.py3-none-any.whl
# Collecting tensorflow~=1.13.0
#   Downloading https://files.pythonhosted.org/packages/ee/89/5b4f6d1dc1d40307feff9068a03484e81d2441099d24a400c95127188783/tensorflow-1.13.2-cp37-cp37m-win_amd64.whl (63.1MB)
# Collecting flask-cors~=3.0
#   Using cached https://files.pythonhosted.org/packages/78/38/e68b11daa5d613e3a91e4bf3da76c94ac9ee0d9cd515af9c1ab80d36f709/Flask_Cors-3.0.8-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: typing~=3.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (3.7.4.1)
# Collecting rasa-core-sdk~=0.14
#   Using cached https://files.pythonhosted.org/packages/bc/5b/343937a872b497079803878e5a6f75deb4aeb00504d32601a0ffd37b90f4/rasa_core_sdk-0.14.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: jsonpickle~=1.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (1.2)
# Requirement already satisfied, skipping upgrade: pykwalify~=1.7.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (1.7.0)
# Collecting jsonschema~=2.6
#   Using cached https://files.pythonhosted.org/packages/77/de/47e35a97b2b05c2fadbec67d44cfcdcd09b8086951b331d82de90d2912da/jsonschema-2.6.0-py2.py3-none-any.whl
# Collecting rocketchat-API~=0.6.0
#   Using cached https://files.pythonhosted.org/packages/89/b5/1b9104733bcadc3d8dc8bcab8f3a73a4ae1dc1de91b4b30fbcb65fa63bd4/rocketchat_API-0.6.35-py3-none-any.whl
# Collecting python-socketio~=3.0
#   Using cached https://files.pythonhosted.org/packages/b5/db/dc823aa0b3397e52ebe8bba62ee39d6b9a088377809bc230d3ad2e5d2448/python_socketio-3.1.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy~=1.16 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (1.17.3+mkl)
# Processing c:\users\asus\appdata\local\pip\cache\wheels\5d\86\c2\49573c0ce194f3073438e56dad49c462fe9c9a69a4fbe7b3fc\flask_jwt_simple-0.0.3-cp37-none-any.whl
# Requirement already satisfied, skipping upgrade: tqdm~=4.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (4.11.2)
# Requirement already satisfied, skipping upgrade: coloredlogs~=10.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (10.0)
# Processing c:\users\asus\appdata\local\pip\cache\wheels\ae\5f\fb\705cb87c56fb25aed2fa6795a1c751ca83b79fc76f69e37d0c\webexteamssdk-1.2-cp37-none-any.whl
# Collecting packaging~=18.0
#   Using cached https://files.pythonhosted.org/packages/89/d1/92e6df2e503a69df9faab187c684585f0136662c12bb1f36901d426f3fab/packaging-18.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: flask~=1.0 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (1.1.1)
# Collecting colorhash~=1.0
#   Using cached https://files.pythonhosted.org/packages/0e/e1/50dbc513aa74e99eca4c47f2a8206711f0bec436fdddd95eebaf7eaaa1aa/colorhash-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: python-dateutil~=2.7 in c:\users\asus\anaconda3\lib\site-packages (from rasa_core) (2.8.0)
# Collecting fbmessenger~=5.0
#   Using cached https://files.pythonhosted.org/packages/51/9d/9a426160e00c3c9d839314685fcec1f60ad04888be4228399dadb37c3226/fbmessenger-5.6.0-py2.py3-none-any.whl
# Processing c:\users\asus\appdata\local\pip\cache\wheels\d1\86\9d\16127127306a92d7fd30267890a5634026c045391979c4c317\colorclass-2.2.0-cp37-none-any.whl
# Processing c:\users\asus\appdata\local\pip\cache\wheels\5d\1a\1e\0350bb3df3e74215cd91325344cc86c2c691f5306eb4d22c77\simplejson-3.16.0-cp37-none-any.whl
# Collecting cloudpickle~=0.6.1
#   Using cached https://files.pythonhosted.org/packages/fc/87/7b7ef3038b4783911e3fdecb5c566e3a817ce3e890e164fc174c088edb1e/cloudpickle-0.6.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: matplotlib~=2.2 in c:\users\asus\anaconda3\lib\site-packages (from rasa_nlu[spacy]) (2.2.2)
# Collecting klein~=17.10
#   Using cached https://files.pythonhosted.org/packages/8a/6b/adc97a7bb3fb781fdd9e49177ad873c1479f87b9745271cbeda81cbb9cc8/klein-17.10.0-py2.py3-none-any.whl
# Collecting boto3~=1.9
#   Downloading https://files.pythonhosted.org/packages/7f/4f/880cb8ed7856bc6f7b1488210259bbd1155c68d3f0a972b0c90b54205e44/boto3-1.10.14-py2.py3-none-any.whl (128kB)
# Processing c:\users\asus\appdata\local\pip\cache\wheels\0c\61\d2\d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e\future-0.17.1-cp37-none-any.whl
# Collecting spacy<=2.0.18,>2.0; extra == "spacy"
#   Downloading https://files.pythonhosted.org/packages/50/31/1496f44c12160282a93c6d36eff5527b89dbc0e6389cf1f4aeeb52caecee/spacy-2.0.18-cp37-cp37m-win_amd64.whl (24.6MB)
# Requirement already satisfied, skipping upgrade: sklearn-crfsuite~=0.3.6; extra == "spacy" in c:\users\asus\anaconda3\lib\site-packages (from rasa_nlu[spacy]) (0.3.6)
# Requirement already satisfied, skipping upgrade: cryptography in c:\users\asus\anaconda3\lib\site-packages (from python-telegram-bot~=11.0->rasa_core) (2.7)
# Requirement already satisfied, skipping upgrade: certifi in c:\users\asus\anaconda3\lib\site-packages (from python-telegram-bot~=11.0->rasa_core) (2019.6.16)
# Requirement already satisfied, skipping upgrade: cffi>=1.11.5; sys_platform == "win32" and platform_python_implementation == "CPython" in c:\users\asus\anaconda3\lib\site-packages (from gevent~=1.3->rasa_core) (1.13.1)
# Requirement already satisfied, skipping upgrade: greenlet>=0.4.14; platform_python_implementation == "CPython" in c:\users\asus\anaconda3\lib\site-packages (from gevent~=1.3->rasa_core) (0.4.15)
# Requirement already satisfied, skipping upgrade: six in c:\users\asus\anaconda3\lib\site-packages (from twilio~=6.0->rasa_core) (1.12.0)
# Collecting PyJWT>=1.4.2
#   Using cached https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in c:\users\asus\anaconda3\lib\site-packages (from networkx~=2.2->rasa_core) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools>=0.7 in c:\users\asus\anaconda3\lib\site-packages (from apscheduler~=3.0->rasa_core) (41.4.0)
# Requirement already satisfied, skipping upgrade: tzlocal>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from apscheduler~=3.0->rasa_core) (2.0.0)
# Collecting websocket-client<0.55.0,>=0.35
#   Using cached https://files.pythonhosted.org/packages/26/2d/f749a5c82f6192d77ed061a38e02001afcba55fe8477336d26a950ab17ce/websocket_client-0.54.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: prompt-toolkit~=2.0 in c:\users\asus\anaconda3\lib\site-packages (from questionary>=1.0.1->rasa_core) (2.0.10)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->rasa_core) (1.25.6)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests~=2.20->rasa_core) (2.8)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.1.4 in c:\users\asus\anaconda3\lib\site-packages (from pydot~=1.4->rasa_core) (2.4.2)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (1.1.0)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (1.1.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (0.33.6)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (0.8.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (3.10.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (1.0.8)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (0.2.2)
# Requirement already satisfied, skipping upgrade: absl-py>=0.1.6 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (0.8.1)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow~=1.13.0->rasa_core) (1.24.3)
# Collecting ConfigArgParse~=0.13.0
#   Downloading https://files.pythonhosted.org/packages/77/61/ae928ce6ab85d4479ea198488cf5ffa371bd4ece2030c0ee85ff668deac5/ConfigArgParse-0.13.0.tar.gz
# Requirement already satisfied, skipping upgrade: docopt>=0.6.2 in c:\users\asus\anaconda3\lib\site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.11 in c:\users\asus\anaconda3\lib\site-packages (from pykwalify~=1.7.0->rasa_core) (5.1.2)
# Collecting python-engineio>=3.2.0
#   Using cached https://files.pythonhosted.org/packages/9b/fb/843f043988306d12f27ae62a82ce26edc7513580e5e089b4911326879f7e/python_engineio-3.10.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\asus\anaconda3\lib\site-packages (from coloredlogs~=10.0->rasa_core) (0.4.1)
# Requirement already satisfied, skipping upgrade: humanfriendly>=4.7 in c:\users\asus\anaconda3\lib\site-packages (from coloredlogs~=10.0->rasa_core) (4.18)
# Collecting requests-toolbelt
#   Using cached https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: Jinja2>=2.10.1 in c:\users\asus\anaconda3\lib\site-packages (from flask~=1.0->rasa_core) (2.10.3)
# Requirement already satisfied, skipping upgrade: Werkzeug>=0.15 in c:\users\asus\anaconda3\lib\site-packages (from flask~=1.0->rasa_core) (0.16.0)
# Requirement already satisfied, skipping upgrade: click>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in c:\users\asus\anaconda3\lib\site-packages (from flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib~=2.2->rasa_nlu[spacy]) (1.1.0)
# Requirement already satisfied, skipping upgrade: incremental in c:\users\asus\anaconda3\lib\site-packages (from klein~=17.10->rasa_nlu[spacy]) (17.5.0)
# Requirement already satisfied, skipping upgrade: Twisted>=15.5 in c:\users\asus\anaconda3\lib\site-packages (from klein~=17.10->rasa_nlu[spacy]) (19.7.0)
# Collecting s3transfer<0.3.0,>=0.2.0
#   Using cached https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl
# Collecting botocore<1.14.0,>=1.13.14
#   Downloading https://files.pythonhosted.org/packages/87/7b/9164e0fd67ced4919131f2bdf3507589a0059f9033feda92b83cc36dae71/botocore-1.13.14-py2.py3-none-any.whl (5.4MB)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in c:\users\asus\anaconda3\lib\site-packages (from boto3~=1.9->rasa_nlu[spacy]) (0.9.4)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (2.0.2)
# Collecting regex==2018.01.10
#   Downloading https://files.pythonhosted.org/packages/3d/22/751518d3f4c22ea23129ffc28d3408d5d4633df460256c54863970f23e1a/regex-2018.01.10-cp37-none-win_amd64.whl (264kB)
# Processing c:\users\asus\appdata\local\pip\cache\wheels\28\77\e4\0311145b9c2e2f01470e744855131f9e34d6919687550f87d1\ujson-1.35-cp37-cp37m-win_amd64.whl
# Processing c:\users\asus\appdata\local\pip\cache\wheels\5b\d7\0f\e58eae695403de585269f4e4a94e0cd6ca60ec0c202936fa4a\dill-0.2.9-cp37-none-any.whl
# Collecting thinc<6.13.0,>=6.12.1
#   Downloading https://files.pythonhosted.org/packages/cf/a1/80aabceed94fe348f8ff0a14b89bfbdce7478783c4bba481b96787c05375/thinc-6.12.1-cp37-cp37m-win_amd64.whl (1.8MB)
# Collecting preshed<2.1.0,>=2.0.1
#   Using cached https://files.pythonhosted.org/packages/b8/e3/0ec374ed2b5046073e735b6e349d759e795fc2e3c83306fbef88efa01921/preshed-2.0.1-cp37-cp37m-win_amd64.whl
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (1.0.2)
# Requirement already satisfied, skipping upgrade: plac<1.0.0,>=0.9.6 in c:\users\asus\anaconda3\lib\site-packages (from spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.9.6)
# Requirement already satisfied, skipping upgrade: python-crfsuite>=0.8.3 in c:\users\asus\anaconda3\lib\site-packages (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.9.6)
# Requirement already satisfied, skipping upgrade: tabulate in c:\users\asus\anaconda3\lib\site-packages (from sklearn-crfsuite~=0.3.6; extra == "spacy"->rasa_nlu[spacy]) (0.8.5)
# Requirement already satisfied, skipping upgrade: asn1crypto>=0.21.0 in c:\users\asus\anaconda3\lib\site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.2.0)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\asus\anaconda3\lib\site-packages (from cffi>=1.11.5; sys_platform == "win32" and platform_python_implementation == "CPython"->gevent~=1.3->rasa_core) (2.19)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\asus\anaconda3\lib\site-packages (from prompt-toolkit~=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied, skipping upgrade: mock>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (3.0.5)
# Requirement already satisfied, skipping upgrade: h5py in c:\users\asus\anaconda3\lib\site-packages (from keras-applications>=1.0.6->tensorflow~=1.13.0->rasa_core) (2.10.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow~=1.13.0->rasa_core) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyreadline; sys_platform == "win32" in c:\users\asus\anaconda3\lib\site-packages (from humanfriendly>=4.7->coloredlogs~=10.0->rasa_core) (2.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\asus\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask~=1.0->rasa_core) (1.1.1)
# Requirement already satisfied, skipping upgrade: zope.interface>=4.4.2 in c:\users\asus\anaconda3\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (4.6.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\asus\anaconda3\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (19.3.0)
# Requirement already satisfied, skipping upgrade: PyHamcrest>=1.9.0 in c:\users\asus\anaconda3\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (1.9.0)
# Requirement already satisfied, skipping upgrade: Automat>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (0.8.0)
# Requirement already satisfied, skipping upgrade: hyperlink>=17.1.1 in c:\users\asus\anaconda3\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (19.0.0)
# Requirement already satisfied, skipping upgrade: constantly>=15.1 in c:\users\asus\anaconda3\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa_nlu[spacy]) (15.1.0)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from botocore<1.14.0,>=1.13.14->boto3~=1.9->rasa_nlu[spacy]) (0.15.2)
# Collecting msgpack-numpy<0.4.4
#   Downloading https://files.pythonhosted.org/packages/ad/45/464be6da85b5ca893cfcbd5de3b31a6710f636ccb8521b17bd4110a08d94/msgpack_numpy-0.4.3.2-py2.py3-none-any.whl
# Collecting cytoolz<0.10,>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/36/f4/9728ba01ccb2f55df9a5af029b48ba0aaca1081bbd7823ea2ee223ba7a42/cytoolz-0.9.0.1.tar.gz (443kB)
# Collecting msgpack<0.6.0,>=0.5.6
#   Using cached https://files.pythonhosted.org/packages/f3/b6/9affbea179c3c03a0eb53515d9ce404809a122f76bee8fc8c6ec9497f51f/msgpack-0.5.6.tar.gz
# Collecting wrapt<1.11.0,>=1.10.0
#   Using cached https://files.pythonhosted.org/packages/a0/47/66897906448185fcb77fc3c2b1bc20ed0ecca81a0f2f88eda3fc5a34fc3d/wrapt-1.10.11.tar.gz
# Requirement already satisfied, skipping upgrade: toolz>=0.8.0 in c:\users\asus\anaconda3\lib\site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy<=2.0.18,>2.0; extra == "spacy"->rasa_nlu[spacy]) (0.10.0)
# Building wheels for collected packages: twilio, ConfigArgParse, cytoolz, msgpack, wrapt
#   Building wheel for twilio (setup.py): started
#   Building wheel for twilio (setup.py): finished with status 'done'
#   Created wheel for twilio: filename=twilio-6.33.0-py2.py3-none-any.whl size=1041700 sha256=001d591ebddea2f0ebc0abd4b73e550ac0fc19022a24fbbd2bbaf9895cfde59c
#   Stored in directory: C:\Users\ASUS\AppData\Local\pip\Cache\wheels\df\a8\26\83b4eff75708191fb1f9c1d6d9f83503c3df0c9ef890a08f9a
#   Building wheel for ConfigArgParse (setup.py): started
#   Building wheel for ConfigArgParse (setup.py): finished with status 'done'
#   Created wheel for ConfigArgParse: filename=ConfigArgParse-0.13.0-cp37-none-any.whl size=17575 sha256=bfe2e4ef754048143e1e61f87fbd1fb8f3e16ad9185c528fa30d86bd254e6a88
#   Stored in directory: C:\Users\ASUS\AppData\Local\pip\Cache\wheels\76\11\eb\12113becd46c0e8a70b8a63f9405e46a1f61d4aaa8532d676b
#   Building wheel for cytoolz (setup.py): started
#   Building wheel for cytoolz (setup.py): finished with status 'done'
#   Created wheel for cytoolz: filename=cytoolz-0.9.0.1-cp37-cp37m-win_amd64.whl size=363571 sha256=490af3bcb2b7000a2b4ffd495345d4e9323254a842e0cf94c54d0fc0ef78be9f
#   Stored in directory: C:\Users\ASUS\AppData\Local\pip\Cache\wheels\88\f3\11\9817b001e59ab04889e8cffcbd9087e2e2155b9ebecfc8dd38
#   Building wheel for msgpack (setup.py): started
#   Building wheel for msgpack (setup.py): finished with status 'done'
#   Created wheel for msgpack: filename=msgpack-0.5.6-cp37-cp37m-win_amd64.whl size=85581 sha256=f58050f9ca66af10b85ff85b26051a6fe6dfdcffb69aef58cfefc296a8290a59
#   Stored in directory: C:\Users\ASUS\AppData\Local\pip\Cache\wheels\f0\02\4c\525b56fce78c415eb8066f6554f9de02792df26b8f882f6d65
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.10.11-cp37-cp37m-win_amd64.whl size=33644 sha256=f036672fbe95b0f76bc9f3175f738cf729c8f750243543617092e82001995735
#   Stored in directory: C:\Users\ASUS\AppData\Local\pip\Cache\wheels\48\5d\04\22361a593e70d23b1f7746d932802efe1f0e523376a74f321e
# Successfully built twilio ConfigArgParse cytoolz msgpack wrapt
# Installing collected packages: mattermostwrapper, future, python-telegram-bot, redis, pytz, PyJWT, twilio, scikit-learn, ruamel.yaml, fakeredis, pymongo, simplejson, jsonschema, packaging, cloudpickle, klein, botocore, s3transfer, boto3, regex, ujson, dill, preshed, msgpack, msgpack-numpy, cytoolz, wrapt, thinc, spacy, rasa-nlu, websocket-client, slackclient, pika, questionary, terminaltables, pydot, tensorflow-estimator, tensorboard, tensorflow, flask-cors, ConfigArgParse, rasa-core-sdk, rocketchat-API, python-engineio, python-socketio, flask-jwt-simple, requests-toolbelt, webexteamssdk, colorhash, fbmessenger, colorclass, rasa-core
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Found existing installation: redis 3.3.11
#     Uninstalling redis-3.3.11:
#       Successfully uninstalled redis-3.3.11
#   Found existing installation: pytz 2019.3
#     Can't uninstall 'pytz'. No files were found to uninstall.
#   Found existing installation: scikit-learn 0.21.3
#     Uninstalling scikit-learn-0.21.3:
#       Successfully uninstalled scikit-learn-0.21.3
#   Found existing installation: ruamel.yaml 0.16.5
#     Uninstalling ruamel.yaml-0.16.5:
#       Successfully uninstalled ruamel.yaml-0.16.5
#   Found existing installation: fakeredis 1.0.5
#     Can't uninstall 'fakeredis'. No files were found to uninstall.
#   Found existing installation: simplejson 3.11.1
#     Uninstalling simplejson-3.11.1:
#       Successfully uninstalled simplejson-3.11.1
# ERROR: xx-ent-wiki-sm 2.2.0 has requirement spacy>=2.2.0, but you'll have spacy 2.0.18 which is incompatible.
# ERROR: jupyterlab-server 1.0.6 has requirement jsonschema>=3.0.1, but you'll have jsonschema 2.6.0 which is incompatible.
# ERROR: en-core-web-sm 2.2.0 has requirement spacy>=2.2.0, but you'll have spacy 2.0.18 which is incompatible.
# ERROR: astroid 2.3.2 has requirement wrapt==1.11.*, but you'll have wrapt 1.10.11 which is incompatible.
# ERROR: rasa-nlu 0.15.1 has requirement tqdm~=4.19, but you'll have tqdm 4.11.2 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\asus\\anaconda3\\lib\\site-packages\\~implejson\\_speedups.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !{python} -m spacy download en_core_web_md
# Out:
# Collecting en_core_web_md==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz#egg=en_core_web_md==2.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz (120.8MB)
#     100% |████████████████████████████████| 120.9MB 16.6MB/s ta 0:00:01   15% |█████                           | 18.5MB 14.5MB/s eta 0:00:08    17% |█████▊                          | 21.6MB 9.6MB/s eta 0:00:11
# Installing collected packages: en-core-web-md
#   Running setup.py install for en-core-web-md ... done
# Successfully installed en-core-web-md-2.0.0
#
#     Linking successful
#     /home/anuj/anaconda3/lib/python3.7/site-packages/en_core_web_md -->
#     /home/anuj/anaconda3/lib/python3.7/site-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %%
# !{python} -m spacy link en_core_web_md en --force;
# Out:
#     Linking successful
#     /home/anuj/anaconda3/lib/python3.7/site-packages/en_core_web_md -->
#     /home/anuj/anaconda3/lib/python3.7/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %%
import rasa_nlu
import rasa_core
import spacy

# %%
print (rasa_core.__version__)
# Out:
# 0.14.5

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("policy_config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 748 (6 distinct intents)
# 	- Found intents: 'inform', 'affirm', 'greet', 'deny', 'thankyou', 'request_info'
# 	- entity examples: 641 (5 distinct entities)
# 	- found entities: 'location', 'cuisine', 'info', 'price', 'people'
#
# INFO:rasa_nlu.utils.spacy_utils:Trying to load spacy model with name 'en_core_web_sm'
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en_core_web_sm'.
# INFO:rasa_nlu.model:Starting to train component SpacyNLP
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SpacyTokenizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SpacyFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component RegexFeaturizer
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component CRFEntityExtractor
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component EntitySynonymMapper
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component SklearnIntentClassifier
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.6s finished
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Successfully saved model into 'C:\Users\ASUS\my-venv\Scripts\weatherbot\rasabot\cloned_repo\12-5-19_ChatbotUsingRasa_AnujSaini\MainProject\models\nlu\default\current'

# %%
# A helper function for prettier output
import json
def pprint(o):   
    print(json.dumps(o, indent=2))
    
pprint(interpreter.parse("looking for expensive restraunts in the east"))
# Out:
# {
#   "intent": {
#     "name": "inform",
#     "confidence": 0.9965960429793732
#   },
#   "entities": [
#     {
#       "start": 12,
#       "end": 21,
#       "value": "hi",
#       "entity": "price",
#       "confidence": 0.9668122972424608,
#       "extractor": "CRFEntityExtractor",
#       "processors": [
#         "EntitySynonymMapper"
#       ]
#     },
#     {
#       "start": 40,
#       "end": 44,
#       "value": "east",
#       "entity": "location",
#       "confidence": 0.9587871027078171,
#       "extractor": "CRFEntityExtractor"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "inform",
#       "confidence": 0.9965960429793732
#     },
#     {
#       "name": "request_info",
#       "confidence": 0.00123021774085691
#     },
#     {
#       "name": "affirm",
#       "confidence": 0.001205324107916052
#     },
#     {
#       "name": "thankyou",
#       "confidence": 0.00042138437544034463
#     },
#     {
#       "name": "deny",
#       "confidence": 0.0003188691964472179
#     },
#     {
#       "name": "greet",
#       "confidence": 0.00022816159996609373
#     }
#   ],
#   "text": "looking for expensive restraunts in the east"
# }

# %%
from rasa_nlu.test import run_evaluation

run_evaluation("nlu.md", model_directory)
# Out:
# INFO:rasa_nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en_core_web_sm'.
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 748 (6 distinct intents)
# 	- Found intents: 'inform', 'affirm', 'greet', 'deny', 'thankyou', 'request_info'
# 	- entity examples: 641 (5 distinct entities)
# 	- found entities: 'location', 'cuisine', 'info', 'price', 'people'
#
# INFO:rasa_nlu.test:Running model for predictions:
# 100%|███████████████████████████████████████████████████████████████████████████████| 748/748 [00:06<00:00, 120.71it/s]
# INFO:rasa_nlu.test:Intent evaluation results:
# INFO:rasa_nlu.test:Intent Evaluation: Only considering those 748 examples that have a defined intent out of 748 examples
# INFO:rasa_nlu.test:F1-Score:  1.0
# INFO:rasa_nlu.test:Precision: 1.0
# INFO:rasa_nlu.test:Accuracy:  1.0
# INFO:rasa_nlu.test:Classification report:
#               precision    recall  f1-score   support
#
#       affirm       1.00      1.00      1.00        40
#         deny       1.00      1.00      1.00        27
#        greet       1.00      1.00      1.00        13
#       inform       1.00      1.00      1.00       625
# request_info       1.00      1.00      1.00        16
#     thankyou       1.00      1.00      1.00        27
#
#    micro avg       1.00      1.00      1.00       748
#    macro avg       1.00      1.00      1.00       748
# weighted avg       1.00      1.00      1.00       748
#
# INFO:rasa_nlu.test:Your model made no errors
# INFO:rasa_nlu.test:Entity evaluation results:
# INFO:rasa_nlu.test:Evaluation for entity extractor: CRFEntityExtractor
# INFO:rasa_nlu.test:F1-Score:  0.9933233740632269
# INFO:rasa_nlu.test:Precision: 0.9935515038368521
# INFO:rasa_nlu.test:Accuracy:  0.993260157904872
# INFO:rasa_nlu.test:Classification report:
#               precision    recall  f1-score   support
#
#      cuisine       0.98      1.00      0.99       418
#         info       1.00      1.00      1.00        24
#     location       0.94      1.00      0.97       205
#    no_entity       1.00      0.99      1.00      4303
#       people       1.00      1.00      1.00        12
#        price       0.96      1.00      0.98       231
#
#    micro avg       0.99      0.99      0.99      5193
#    macro avg       0.98      1.00      0.99      5193
# weighted avg       0.99      0.99      0.99      5193
# {'intent_evaluation': {'predictions': [{'text': 'uh yes im looking for a cheap restaurant in the west part of town',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.48504179866827074},
#    {'text': 'yeah a cheap restaurant serving international food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.472638523785342},
#    {'text': 'correct',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4849565427060273},
#    {'text': 'ye',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.540608740818634},
#    {'text': 'uh yes restaurant that serves danish food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.7446809238201089},
#    {'text': "let's do it",
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4665063510531002},
#    {'text': 'yeah',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.859967019302792},
#    {'text': 'yes that sells korean food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.948313183845474},
#    {'text': 'yes can i have can i get swedish food in any area',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4663495839949534},
#    {'text': 'yes id like an expensive restaurant in the east part of town',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.49877988228740033},
#    {'text': 'uh yes a cheap restaurant',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.7985226232678981},
#    {'text': 'yes that serves korean food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8388645625706028},
#    {'text': 'um yes',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.7964217382615333},
#    {'text': 'yes knocking',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8537660197277245},
#    {'text': 'yes italian food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.5696749469179626},
#    {'text': 'yes in the moderately priced',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.483112699253265},
#    {'text': 'thats correct gastropub food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.48020211945971886},
#    {'text': 'uh yes im looking for a cheap restaurant that serves medetanian food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4808188811252371},
#    {'text': 'yes yes',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8991979339867154},
#    {'text': 'uh yes can i find a restaurant in the east part of town that serves chinese',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4800066248949282},
#    {'text': 'uh yes im looking for malaysian food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.7215048511983702},
#    {'text': 'right',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8197667017998258},
#    {'text': 'yea',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8291704751667757},
#    {'text': 'yes',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8724602181362201},
#    {'text': 'yes i am in the east part of town right now and i am looking for any place that serves indonesian food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.48009976320000974},
#    {'text': 'yes south part of town',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.6964887819150681},
#    {'text': 'yes right',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.8381405060860899},
#    {'text': 'yes and i dont care about the price range',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4694843444557879},
#    {'text': 'yeah i need to find',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.47340862866993255},
#    {'text': 'uh yes i need the north part of town',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.7887346366892837},
#    {'text': 'uh yeah im looking for a restaurant in the south part of town and that serves kosher food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4823024979991651},
#    {'text': 'yea thank you good bye',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.6766438714959437},
#    {'text': 'yes can i have',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.9527741465350389},
#    {'text': 'yes and in french please',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.7954235179708378},
#    {'text': 'uh yes can i find a moderately priced restaurant and it serve it should serve brazilian food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.5266772004784412},
#    {'text': 'right on good bye peace',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.46812466993609986},
#    {'text': 'yes in the west part of town',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.6767884788090115},
#    {'text': 'yes barbecue food',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.6884984327553477},
#    {'text': 'i love that',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.4562245163527511},
#    {'text': 'yes spanish restaurant',
#     'intent': 'affirm',
#     'predicted': 'affirm',
#     'confidence': 0.5052584447482458},
#    {'text': 'no danish food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9005802419552572},
#    {'text': 'no north',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9564949075368081},
#    {'text': 'no',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9895567349930341},
#    {'text': 'no new selection',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9043012209299601},
#    {'text': 'no im looking for pan asian',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.7659358694509553},
#    {'text': 'no thanks',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9652539556750448},
#    {'text': 'no i want american food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.7498684996906416},
#    {'text': 'no thank you good bye',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.7113955630876645},
#    {'text': 'no thank you',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9528846814514272},
#    {'text': 'no spanish food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.8975937045388463},
#    {'text': 'no im looking in the south of the town',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.7981865743568026},
#    {'text': 'no indian food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.975740707488024},
#    {'text': 'uh no',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9162987473519167},
#    {'text': 'breath no american food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.755589439664954},
#    {'text': 'no the south part',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9370149116402808},
#    {'text': 'oh no and cheap',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.7152038755039808},
#    {'text': 'no spanish',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.981678029415023},
#    {'text': 'no british food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9267961110655818},
#    {'text': 'no south part of town',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.8127456454784601},
#    {'text': 'no im looking for one that serves vietnamese food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.7668235402627753},
#    {'text': 'do you have something else',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.6997599515604574},
#    {'text': 'no chinese',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9881678823322928},
#    {'text': 'no i want halal food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.8266992566406842},
#    {'text': 'no hungarian food',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9619799033565507},
#    {'text': 'no center',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9907449619212522},
#    {'text': 'no this does not work for me',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.8491440111867211},
#    {'text': 'no thai',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.9794278671415947},
#    {'text': 'hi there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.6948862651943802},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7394315710786376},
#    {'text': 'hey',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7399804420346356},
#    {'text': 'hi',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.8076381967337886},
#    {'text': 'hey bot',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7071815907350019},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.8118636016044313},
#    {'text': 'goodmorning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7087566262406517},
#    {'text': 'hello',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7367700102962881},
#    {'text': 'goodevening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7845514840307991},
#    {'text': 'goodafternoon',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7476933426438959},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7746670066343518},
#    {'text': 'morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.8984187350645709},
#    {'text': 'good afternoon',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7783984670423548},
#    {'text': 'afghan food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9999023920615221},
#    {'text': 'how bout asian oriental',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9688153005393393},
#    {'text': 'im looking for a moderately priced restaurant in the east part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9540243000987084},
#    {'text': 'find moderately priced restaurant in the west part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9335135640882204},
#    {'text': 'what about indian food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9996373082233986},
#    {'text': 'south part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9667724826473787},
#    {'text': 'uh how about turkish type of food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9768766127310099},
#    {'text': 'yea im looking for a really cheap restaurant',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9086629375725834},
#    {'text': 'a moderate restaurant in the west part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9799745714826078},
#    {'text': 'um english',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9886920653811725},
#    {'text': 'im looking for tuscan food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9780838090049149},
#    {'text': 'i need a moderately priced restaurant in the west part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9385672024778355},
#    {'text': 'cheap restaurant in the east of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9415421273395652},
#    {'text': 'id like moderately priced moroccan food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9826221132355173},
#    {'text': 'im looking for an expensive restaurant in the east town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9714677441059932},
#    {'text': 'moderately priced food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9903105580410193},
#    {'text': 'restaurant north part of town seafood',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.991021692741093},
#    {'text': 'moderately priced restaurant in the south part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.955643958167957},
#    {'text': 'north part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9858531137285158},
#    {'text': 'north part',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9839187048575887},
#    {'text': 'french food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9966085119478244},
#    {'text': 'serves british food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9984066501517124},
#    {'text': 'i need a moderately priced restaurant',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.974835576059181},
#    {'text': 'i want a moderately priced restaurant in the west part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9395932106538079},
#    {'text': 'i want a cheap restaurant in the south part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9550225699651977},
#    {'text': 'id like a restaurant in any area that it serves canapes',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9153219774573063},
#    {'text': 'im looking for a restaurant in the south part of town serving jamaican food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9519992291480391},
#    {'text': 'um what about italian food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.979431460011416},
#    {'text': 'im looking for a cheap restaurant in the north part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9629047677236671},
#    {'text': 'the south part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.
',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.997277155963919},
#    {'text': 'im looking for a restaurant in the south part of town serving korean food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9460476226131349},
#    {'text': 'i want to find a expensive restaurant in the south part of town',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9784160164161038},
#    {'text': 'i want a moderately priced',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9792310147182813},
#    {'text': 'canapes food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9917226322841449},
#    {'text': 'ok how about chinese food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9952126710360041},
#    {'text': 'i need a restaurant in the center of town that serves spanish food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9508731296993244},
#    {'text': 'uh world food',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9079016501712182},
#    {'text': 'i need a cheap restaurant',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9816034416301674},
#    {'text': 'im looking for thai',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9691681310858082},
#    {'text': 'do you have their address',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7734769612552834},
#    {'text': 'do you have its phone number',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7620212948992174},
#    {'text': 'can i have their phone number',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.771991260938183},
#    {'text': 'what is the phone number of the restaurant',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7466461047531294},
#    {'text': 'what is their address',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.8120651638768767},
#    {'text': 'may i have the address of the restaurant',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7422966393031809},
#    {'text': 'whats their address',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.8041132590985764},
#    {'text': 'do you have their phone number',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7820547829149161},
#    {'text': 'give me their phone number',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7473788907735325},
#    {'text': 'whats their phone number',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.8094469711901922},
#    {'text': 'do you have its address',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7437922344927912},
#    {'text': 'may i have the phone number of the restaurant',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7509856417019046},
#    {'text': 'what is their phone number',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.809696056196479},
#    {'text': 'give me their address',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7484026183637398},
#    {'text': 'can i have their address',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7575064215067754},
#    {'text': 'what is the address of the restaurant',
#     'intent': 'request_info',
#     'predicted': 'request_info',
#     'confidence': 0.7535234478813563},
#    {'text': 'um thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8071634254112027},
#    {'text': 'okay cool uh good bye thank you',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.7945990973337655},
#    {'text': 'okay thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8578553536175125},
#    {'text': 'you rock',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8340137804789068},
#    {'text': 'and thats all thank you and good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.7744191722604912},
#    {'text': 'thank you and good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.9296887131154848},
#    {'text': 'sorry about my mistakes thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8130491458751965},
#    {'text': 'noise thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.843929686722983},
#    {'text': 'thank you goodbye noise',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8191637391542737},
#    {'text': 'okay thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.9281442304309325},
#    {'text': 'uh thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8039127984976023},
#    {'text': 'thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.9354605440557521},
#    {'text': 'thank you goodbye noise thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.9139775053623409},
#    {'text': 'breath thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.9408222151095449},
#    {'text': 'thank you',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8020541060148386},
#    {'text': 'okay thank you',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8757713485411578},
#    {'text': 'thanks goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.9322607015894057},
#    {'text': 'ah thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8150390084657223},
#    {'text': 'thank you noise',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.7901837210349372},
#    {'text': 'thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.82265048306441},
#    {'text': 'breath thank you very much goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8372271149403682},
#    {'text': 'thanks',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8378769897466176},
#    {'text': 'noise thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.891084206641678},
#    {'text': 'unintelligible thank you goodbye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8565225838634549},
#    {'text': 'uh okay thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8009141525692661},
#    {'text': 'thank you bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8012634614723261},
#    {'text': 'um okay thank you good bye',
#     'intent': 'thankyou',
#     'predicted': 'thankyou',
#     'confidence': 0.8158397879693332}],
#   'report': '              precision    recall  f1-score   support\n\n      affirm       1.00      1.00      1.00        40\n        deny       1.00      1.00      1.00        27\n       greet       1.00      1.00      1.00        13\n      inform       1.00      1.00      1.00       625\nrequest_info       1.00      1.00      1.00        16\n    thankyou       1.00      1.00      1.00        27\n\n   micro avg       1.00      1.00      1.00       748\n   macro avg       1.00      1.00      1.00       748\nweighted avg       1.00      1.00      1.00       748\n',
#   'precision': 1.0,
#   'f1_score': 1.0,
#   'accuracy': 1.0},
#  'entity_evaluation': {'CRFEntityExtractor': {'report': '              precision    recall  f1-score   support\n\n     cuisine       0.98      1.00      0.99       418\n        info       1.00      1.00      1.00        24\n    location       0.94      1.00      0.97       205\n   no_entity       1.00      0.99      1.00      4303\n      people       1.00      1.00      1.00        12\n       price       0.96      1.00      0.98       231\n\n   micro avg       0.99      0.99      0.99      5193\n   macro avg       0.98      1.00      0.99      5193\nweighted avg       0.99      0.99      0.99      5193\n',
#    'precision': 0.9935515038368521,
#    'f1_score': 0.9933233740632269,
#    'accuracy': 0.993260157904872}}}

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.1

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\asus\anaconda3\lib\site-packages (0.13)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygraphviz

# %%
# !apt-get -qq install -y graphviz libgraphviz-dev pkg-config;
# !breq install graphviz

# !{python} -m pip install pygraphviz;
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'breq' is not recognized as an internal or external command,
# operable program or batch file.
# '{python}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image
from rasa_core.agent import Agent

agent = Agent('domain.yml')
agent.visualize("stories.md", "story_graph.jpeg", max_history=2)
Image(filename="story_graph.jpeg")
# Out:
# Processed Story Blocks: 100%|██████████| 1000/1000 [00:01<00:00, 525.65it/s, # trackers=1]

# %%
# !python -m rasa_core.train -d domain.yml -s stories.md -o models/dialogue

print("Finished training!")
# Out:
# :0: UserWarning: You do not have a working installation of the service_identity module: 'No module named 'service_identity''.  Please install it from <https://pypi.python.org/pypi/service_identity> and make sure all of its dependencies are satisfied.  Without the service_identity module, Twisted can perform only rudimentary TLS client hostname verification.  Many valid certificate/hostname mappings may be rejected.
# /home/anuj/anaconda3/lib/python3.7/runpy.py:125: RuntimeWarning: 'rasa_core.train' found in sys.modules after import of package 'rasa_core', but prior to execution of 'rasa_core.train'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2019-05-12 00:21:45 INFO     apscheduler.scheduler  - Scheduler started
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# Processed Story Blocks: 100%|█| 1000/1000 [00:00<00:00, 1408.24it/s, # trackers=1]
# Processed Story Blocks: 100%|█| 1000/1000 [00:01<00:00, 950.98it/s, # trackers=1]
# Processed Story Blocks: 100%|█| 1000/1000 [00:01<00:00, 901.21it/s, # trackers=1]
# Processed Story Blocks: 100%|█| 1000/1000 [00:01<00:00, 787.68it/s, # trackers=1]
# 2019-05-12 00:21:54.423294: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-12 00:21:54.625899: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 
# 511/511 [==============================] - 0s 133us/sample - loss: 0.1229 - acc: 0.9706
# Epoch 83/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1286 - acc: 0.9648
# Epoch 84/100
# 511/511 [==============================] - 0s 104us/sample - loss: 0.1169 - acc: 0.9746
# Epoch 85/100
# 511/511 [==============================] - 0s 104us/sample - loss: 0.1348 - acc: 0.9687
# Epoch 86/100
# 511/511 [==============================] - 0s 102us/sample - loss: 0.1371 - acc: 0.9530
# Epoch 87/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1267 - acc: 0.9628
# Epoch 88/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1580 - acc: 0.9550
# Epoch 89/100
# 511/511 [==============================] - 0s 109us/sample - loss: 0.1422 - acc: 0.9628
# Epoch 90/100
# 511/511 [==============================] - 0s 136us/sample - loss: 0.1309 - acc: 0.9648
# Epoch 91/100
# 511/511 [==============================] - 0s 148us/sample - loss: 0.1355 - acc: 0.9609
# Epoch 92/100
# 511/511 [==============================] - 0s 131us/sample - loss: 0.1352 - acc: 0.9550
# Epoch 93/100
# 511/511 [==============================] - 0s 106us/sample - loss: 0.1078 - acc: 0.9785
# Epoch 94/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1220 - acc: 0.9609
# Epoch 95/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1033 - acc: 0.9726
# Epoch 96/100
# 511/511 [==============================] - 0s 108us/sample - loss: 0.1168 - acc: 0.9648
# Epoch 97/100
# 511/511 [==============================] - 0s 104us/sample - loss: 0.1200 - acc: 0.9589
# Epoch 98/100
# 511/511 [==============================] - 0s 102us/sample - loss: 0.1063 - acc: 0.9706
# Epoch 99/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1051 - acc: 0.9804
# Epoch 100/100
# 511/511 [==============================] - 0s 103us/sample - loss: 0.1130 - acc: 0.9687
# 2019-05-12 00:22:03 INFO     rasa_core.policies.keras_policy  - Done fitting keras policy model
# Processed actions: 331it [00:00, 11076.57it/s, # examples=329]
# 2019-05-12 00:22:06 INFO     rasa_core.agent  - Persisted model to '/home/anuj/Documents/rasa-restaurant/models/dialogue'
# Finished training!

# %%
import IPython
from IPython.display import clear_output, HTML, display
from rasa_core.agent import Agent
from rasa_core.interpreter import RasaNLUInterpreter
import time

interpreter = RasaNLUInterpreter('models/nlu/default/current')
messages = ["Hi! you can chat in this window. Type 'stop' to end the conversation."]
agent = Agent.load('models/dialogue', interpreter=interpreter)

def chatlogs_html(messages):
    messages_html = "".join(["<p>{}</p>".format(m) for m in messages])
    chatbot_html = """<div class="chat-window" {}</div>""".format(messages_html)
    return chatbot_html


while True:
    clear_output()
    display(HTML(chatlogs_html(messages)))
    time.sleep(0.3)
    a = input()
    messages.append(a)
    if a == 'stop':
        break
    responses = agent.handle_message(a)
    for r in responses:
        messages.append(r.get("text"))

# %%
# !python -m rasa_core.train interactive -o models/dialogue -d domain.yml -c policy_config.yml -s stories.md --nlu models/nlu/default/current --endpoints endpoints.yml
